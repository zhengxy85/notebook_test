# %% [markdown]
# # this is a test of ipython notebook

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(range(10))
plt.title('this is a test')
plt.xlabel('x')
plt.show()

# %% [markdown]
# # the second figure

# %%
# %matplotlib inline
plt.plot(range(10))
plt.title('this is the second test')
plt.xlabel('x')
plt.show()

# %% [markdown]
# # the third figure

# %%
# %matplotlib inline
plt.plot(range(10))
plt.title('this is the third test')
plt.xlabel('x')
plt.show()

# %%
1+2
# Out:
# 3

# %%
# %matplotlib inline
import sys
sys.path.append('/home019hb/ph05/matlab/python_function/forsharing/read_nefis')
import read_delft3d
print dir(read_delft3d)
a=read_delft3d.nefis2pd('/home019hb/ph05/delft3d_run/hutai/east_china_sea/model/trih-east')
a.plot()
plt.show()
# Out:
# ['__builtins__', '__doc__', '__file__', '__name__', '__package__', 'file_type', 'gettimes', 'nefis2pd', 'nefis2pdall', 'read_delft3d']
